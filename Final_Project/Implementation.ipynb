# %% [markdown]
# <div style="display: flex; justify-content: space-between; align-items: center; background-color: white; padding: 20px;">
#     <img src="./Images/university_logo.png" alt="University Logo" style="height: 100px;">
#     <div style="text-align: center; font-family: Arial, sans-serif; color: black;">
#         <h1>Social Network</h1>
#         <h3>Final Project</h3>
#         <p><strong>Sara Sadat Nasr Azadani</strong></p>
#         <p><strong>Student ID</strong>: 810104272</p>
#     </div>
#     <img src="./Images/faculty_logo.png" alt="Faculty Logo" style="height: 100px;">
# </div>

# %% [markdown]
# <div style="background-color: #cce5ff; padding: 10px; border: 1px solid #b3d7ff;">
#     <strong style="color:black;">Question 1: Parzen Windows</strong>
# </div>
